# %% [markdown]
# # Stable Diffusion v1.5

# %% [markdown]
# ### Libraries installation

# %%
# !pip install diffusers -q
# Out:
#      |████████████████████████████████| 503 kB 28.0 MB/s
#      |████████████████████████████████| 182 kB 75.5 MB/s

# %%
# !pip install --upgrade transformers -q
# Out:
#      |████████████████████████████████| 5.8 MB 39.5 MB/s
#      |████████████████████████████████| 7.6 MB 48.3 MB/s

# %% [markdown]
# ### GPU Check

# %%
# !nvidia-smi
# Out:
# Thu Dec 15 20:20:28 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   72C    P0    30W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# ### Torch importing and Generator

# %%
import torch

device = 'cuda'

generator = torch.Generator(device).manual_seed(1024)

# %% [markdown]
# ### Hugging Face Login

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# Token is valid.
# Your token has been saved in your configured git credential helpers (store).
# Your token has been saved to /root/.huggingface/token
# Login successful

# %% [markdown]
# ### Stable Diffusion Model and Pipeline

# %%
model_id = "runwayml/stable-diffusion-v1-5"

# %%
from diffusers import StableDiffusionPipeline

# %%
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16, revision="fp16", use_auth_token=True)
pipe = pipe.to(device)
# Out:
# Downloading:   0%|          | 0.00/543 [00:00<?, ?B/s]
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# Downloading:   0%|          | 0.00/342 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.70k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/608M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/307 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/636 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/246M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/525k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/472 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/822 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/806 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.72G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/609 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/167M [00:00<?, ?B/s]
# ...

# %% [markdown]
# ### Images Generation

# %%
prompt = "beautiful japanise woman, black hair, sitting on the sofa, drinking wine"
image = pipe(prompt).images[0]  
    
image.save("sd_img.png")

image
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FBBFE070DF0>

# %%
prompt = "A cute girl close-up portrait curly-haired persian girl, burning halo, intricate artwork by Tooth Wu and wlop and beeple, greg rutkowski, very coherent symmetrical artwork, cinematic, hyper realism, high detail, octane render, unreal engine, 8k, Vibrant colors, Smooth gradients, High contrast, depth of field"
image = pipe(prompt).images[0]  
    
image.save("sd_img.png")

image
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FBBFC795F10>

# %%
prompt = "mountain lanscape, sunny, grass, peace, clean sky"
image = pipe(prompt).images[0]  
    
image.save("sd_img.png")

image
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FBBFC78CBE0>
