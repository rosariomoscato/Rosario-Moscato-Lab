# %% [markdown]
# # Music Genre Classification
#
# [GTZAN Dataset on Kaggle](https://www.kaggle.com/andradaolteanu/gtzan-dataset-music-genre-classification)
#
# Used libraries:
# - librosa, librosa.display
# - matplotlib
# - numpy
# - os
# - math
# - json

# %%
import numpy as np
import librosa, librosa.display
import matplotlib.pyplot as plt

# %%
example_file = "disco.00001.wav"

# %%
# load audio file with Librosa
signal, sample_rate = librosa.load(example_file)

# %%
print(signal)
# Out:
# [-0.18777466 -0.23693848 -0.15542603 ...  0.03741455  0.10574341
#   0.09619141]

# %%
print(sample_rate)
# Out:
# 22050

# %%
FIG_SIZE = (16,8)

# %%
# WAVEFORM
plt.figure(figsize=FIG_SIZE)
librosa.display.waveplot(signal, sample_rate, alpha=0.5)
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.title("Waveform")
# Out:
# Text(0.5, 1.0, 'Waveform')

# %%
# Fourier Transform (FFT) - Frequency Domain
fft = np.fft.fft(signal)

# %%
# Calculate the Magnitude (abs values on complex numbers)
spectrum = np.abs(fft)

# %%
# Create the Frequency variable
f = np.linspace(0, sample_rate, len(spectrum))

# %%
# Plot Spectrum
plt.figure(figsize=FIG_SIZE)
plt.plot(f, spectrum, alpha=0.5)
plt.xlabel("Frequency")
plt.ylabel("Magnitude")
plt.title("Power Spectrum")
# Out:
# Text(0.5, 1.0, 'Power Spectrum')

# %%
# Take half of the spectrum and frequency
left_spectrum = spectrum[:int(len(spectrum)/2)]
left_f = f[:int(len(spectrum)/2)]

# %%
# Plot Spectrum
plt.figure(figsize=FIG_SIZE)
plt.plot(left_f, left_spectrum, alpha=0.5)
plt.xlabel("Frequency")
plt.ylabel("Magnitude")
plt.title("Power Spectrum")
# Out:
# Text(0.5, 1.0, 'Power Spectrum')

# %%
# Spectrogram (STFT)
hop_length = 512 # num. of samples
n_fft = 2048 # num. of samples for window

# %%
# Perform STFT
stft = librosa.stft(signal, n_fft=n_fft, hop_length=hop_length)

# %%
# Calculate the Magnitude (abs values on complex numbers)
spectrogram = np.abs(stft)

# %%
# Plot the Spectrogram
plt.figure(figsize=FIG_SIZE)
librosa.display.specshow(spectrogram, sr=sample_rate, hop_length=hop_length)
plt.xlabel("Time")
plt.ylabel("Frequency")
plt.colorbar()
plt.title("Spectrogram")
# Out:
# Text(0.5, 1.0, 'Spectrogram')

# %%
# Apply Logarithm to get values in Decibels
log_spectrogram = librosa.amplitude_to_db(spectrogram)

# %%
# Plot the Spectrogram in Decibels
plt.figure(figsize=FIG_SIZE)
librosa.display.specshow(log_spectrogram, sr=sample_rate, hop_length=hop_length)
plt.xlabel("Time")
plt.ylabel("Frequency")
plt.colorbar(format="%+2.0f dB")
plt.title("Spectrogram (dB)")
# Out:
# Text(0.5, 1.0, 'Spectrogram (dB)')

# %%
# MFCCs (we use 13 MFCCs)
MFCCs = librosa.feature.mfcc(signal, sample_rate, n_fft=n_fft, hop_length=hop_length, n_mfcc=13)

# %%
# Plot MFCCs
plt.figure(figsize=FIG_SIZE)
librosa.display.specshow(MFCCs, sr=sample_rate, hop_length=hop_length)
plt.xlabel("Time")
plt.ylabel("MFCC coefficients")
plt.colorbar()
plt.title("MFCCs")
# Out:
# Text(0.5, 1.0, 'MFCCs')

# %%
import json
import os
import math

# %%
DATASET_PATH = "/content/drive/MyDrive/genres_original"
JSON_PATH = "data_10.json"
SAMPLE_RATE = 22050
TRACK_DURATION = 30 # measured in seconds
SAMPLES_PER_TRACK = SAMPLE_RATE * TRACK_DURATION

# %%
def save_mfcc(dataset_path, json_path, num_mfcc=13, n_fft=2048, hop_length=512, num_segments=5):
    """Extracts MFCCs from music dataset and saves them into a json file along with genre labels.
        """

    # dictionary to store mapping, labels, and MFCCs
    data = {
        "mapping": [],
        "labels": [],
        "mfcc": []
    }

    samples_per_segment = int(SAMPLES_PER_TRACK / num_segments)
    num_mfcc_vectors_per_segment = math.ceil(samples_per_segment / hop_length)

    # loop through all genre sub-folder
    for i, (dirpath, dirnames, filenames) in enumerate(os.walk(dataset_path)):

        # ensure we're processing a genre sub-folder level
        if dirpath is not dataset_path:

            # save genre label (i.e., sub-folder name) in the mapping
            semantic_label = dirpath.split("/")[-1]
            data["mapping"].append(semantic_label)
            print("\nProcessing: {}".format(semantic_label))

            # process all audio files in genre sub-dir
            for f in filenames:

		# load audio file
                file_path = os.path.join(dirpath, f)
                signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE)

                # process all segments of audio file
                for d in range(num_segments):

                    # calculate start and finish sample for current segment
                    start = samples_per_segment * d
                    finish = start + samples_per_segment

                    # extract mfcc
                    mfcc = librosa.feature.mfcc(signal[start:finish], sample_rate, n_mfcc=num_mfcc, n_fft=n_fft, hop_length=hop_length)
                    mfcc = mfcc.T

                    # store only mfcc feature with expected number of vectors
                    if len(mfcc) == num_mfcc_vectors_per_segment:
                        data["mfcc"].append(mfcc.tolist())
                        data["labels"].append(i-1)
                        print("{}, segment:{}".format(file_path, d+1))

    # save MFCCs to json file
    with open(json_path, "w") as fp:
        json.dump(data, fp, indent=4)

# %%
save_mfcc(DATASET_PATH, JSON_PATH, num_segments=10)
# Out:
# Output streaming troncato alle ultime 5000 righe.
# /content/drive/MyDrive/genres_original/pop/pop.00003.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00003.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00003.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00004.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00004.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00004.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00004.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00004.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00004.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00004.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00004.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00004.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00004.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00002.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00002.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00002.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00002.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00002.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00002.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00002.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00002.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00002.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00002.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00005.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00005.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00005.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00005.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00005.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00005.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00005.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00005.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00005.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00005.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00001.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00001.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00001.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00001.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00001.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00001.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00001.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00001.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00001.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00001.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00000.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00000.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00000.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00000.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00000.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00000.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00000.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00000.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00000.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00000.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00006.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00006.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00006.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00006.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00006.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00006.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00006.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00006.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00006.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00006.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00011.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00011.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00011.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00011.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00011.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00011.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00011.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00011.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00011.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00011.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00018.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00018.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00018.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00018.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00018.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00018.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00018.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00018.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00018.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00018.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00009.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00009.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00009.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00009.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00009.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00009.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00009.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00009.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00009.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00009.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00017.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00017.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00017.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00017.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00017.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00017.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00017.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00017.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00017.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00017.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00012.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00012.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00012.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00012.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00012.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00012.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00012.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00012.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00012.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00012.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00019.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00019.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00019.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00019.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00019.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00019.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00019.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00019.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00019.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00019.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00013.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00013.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00013.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00013.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00013.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00013.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00013.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00013.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00013.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00013.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00010.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00010.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00010.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00010.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00010.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00010.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00010.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00010.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00010.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00010.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00008.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00008.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00008.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00008.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00008.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00008.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00008.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00008.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00008.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00008.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00016.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00016.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00016.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00016.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00016.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00016.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00016.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00016.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00016.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00016.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00014.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00014.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00014.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00014.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00014.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00014.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00014.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00014.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00014.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00014.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00015.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00015.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00015.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00015.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00015.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00015.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00015.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00015.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00015.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00015.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00007.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00007.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00007.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00007.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00007.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00007.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00007.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00007.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00007.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00007.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00020.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00020.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00020.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00020.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00020.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00020.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00020.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00020.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00020.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00020.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00029.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00029.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00029.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00029.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00029.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00029.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00029.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00029.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00029.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00029.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00033.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00033.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00033.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00033.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00033.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00033.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00033.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00033.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00033.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00033.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00028.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00028.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00028.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00028.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00028.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00028.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00028.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00028.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00028.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00028.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00021.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00021.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00021.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00021.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00021.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00021.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00021.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00021.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00021.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00021.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00032.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00032.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00032.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00032.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00032.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00032.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00032.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00032.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00032.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00032.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00027.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00027.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00027.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00027.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00027.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00027.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00027.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00027.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00027.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00027.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00024.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00024.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00024.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00024.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00024.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00024.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00024.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00024.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00024.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00024.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00031.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00031.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00031.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00031.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00031.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00031.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00031.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00031.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00031.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00031.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00022.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00022.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00022.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00022.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00022.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00022.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00022.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00022.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00022.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00022.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00034.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00034.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00034.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00034.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00034.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00034.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00034.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00034.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00034.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00034.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00026.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00026.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00026.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00026.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00026.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00026.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00026.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00026.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00026.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00026.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00030.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00030.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00030.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00030.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00030.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00030.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00030.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00030.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00030.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00030.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00023.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00023.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00023.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00023.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00023.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00023.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00023.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00023.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00023.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00023.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00025.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00025.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00025.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00025.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00025.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00025.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00025.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00025.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00025.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00025.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00043.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00043.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00043.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00043.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00043.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00043.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00043.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00043.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00043.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00043.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00041.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00041.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00041.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00041.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00041.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00041.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00041.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00041.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00041.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00041.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00039.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00039.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00039.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00039.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00039.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00039.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00039.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00039.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00039.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00039.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00046.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00046.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00046.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00046.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00046.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00046.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00046.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00046.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00046.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00046.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00037.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00037.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00037.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00037.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00037.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00037.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00037.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00037.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00037.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00037.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00048.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00048.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00048.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00048.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00048.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00048.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00048.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00048.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00048.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00048.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00038.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00038.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00038.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00038.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00038.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00038.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00038.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00038.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00038.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00038.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00036.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00036.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00036.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00036.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00036.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00036.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00036.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00036.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00036.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00036.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00035.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00035.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00035.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00035.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00035.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00035.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00035.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00035.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00035.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00035.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00044.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00044.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00044.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00044.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00044.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00044.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00044.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00044.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00044.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00044.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00045.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00045.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00045.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00045.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00045.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00045.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00045.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00045.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00045.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00045.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00042.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00042.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00042.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00042.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00042.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00042.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00042.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00042.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00042.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00042.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00047.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00047.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00047.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00047.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00047.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00047.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00047.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00047.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00047.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00047.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00040.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00040.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00040.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00040.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00040.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00040.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00040.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00040.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00040.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00040.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00058.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00058.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00058.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00058.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00058.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00058.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00058.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00058.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00058.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00058.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00059.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00059.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00059.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00059.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00059.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00059.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00059.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00059.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00059.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00059.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00050.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00050.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00050.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00050.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00050.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00050.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00050.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00050.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00050.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00050.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00049.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00049.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00049.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00049.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00049.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00049.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00049.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00049.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00049.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00049.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00055.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00055.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00055.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00055.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00055.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00055.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00055.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00055.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00055.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00055.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00052.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00052.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00052.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00052.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00052.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00052.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00052.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00052.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00052.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00052.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00054.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00054.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00054.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00054.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00054.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00054.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00054.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00054.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00054.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00054.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00062.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00062.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00062.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00062.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00062.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00062.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00062.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00062.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00062.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00062.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00057.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00057.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00057.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00057.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00057.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00057.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00057.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00057.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00057.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00057.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00053.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00053.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00053.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00053.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00053.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00053.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00053.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00053.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00053.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00053.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00056.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00056.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00056.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00056.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00056.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00056.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00056.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00056.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00056.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00056.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00060.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00060.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00060.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00060.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00060.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00060.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00060.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00060.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00060.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00060.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00061.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00061.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00061.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00061.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00061.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00061.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00061.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00061.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00061.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00061.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00051.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00051.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00051.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00051.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00051.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00051.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00051.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00051.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00051.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00051.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00069.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00069.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00069.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00069.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00069.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00069.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00069.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00069.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00069.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00069.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00067.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00067.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00067.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00067.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00067.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00067.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00067.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00067.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00067.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00067.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00072.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00072.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00072.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00072.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00072.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00072.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00072.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00072.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00072.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00072.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00066.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00066.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00066.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00066.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00066.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00066.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00066.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00066.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00066.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00066.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00073.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00073.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00073.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00073.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00073.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00073.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00073.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00073.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00073.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00073.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00071.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00071.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00071.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00071.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00071.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00071.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00071.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00071.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00071.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00071.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00065.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00065.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00065.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00065.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00065.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00065.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00065.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00065.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00065.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00065.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00063.wav, segment:1
# /content/drive/MyDrive/genres_original/pop/pop.00063.wav, segment:2
# /content/drive/MyDrive/genres_original/pop/pop.00063.wav, segment:3
# /content/drive/MyDrive/genres_original/pop/pop.00063.wav, segment:4
# /content/drive/MyDrive/genres_original/pop/pop.00063.wav, segment:5
# /content/drive/MyDrive/genres_original/pop/pop.00063.wav, segment:6
# /content/drive/MyDrive/genres_original/pop/pop.00063.wav, segment:7
# /content/drive/MyDrive/genres_original/pop/pop.00063.wav, segment:8
# /content/drive/MyDrive/genres_original/pop/pop.00063.wav, segment:9
# /content/drive/MyDrive/genres_original/pop/pop.00063.wav, segment:10
# /content/drive/MyDrive/genres_original/pop/pop.00068.wav, segment:1
# ...
# /content/drive/MyDrive/genres_original/disco/disco.00083.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00074.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00074.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00074.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00074.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00074.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00074.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00074.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00074.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00074.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00074.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00082.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00082.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00082.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00082.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00082.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00082.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00082.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00082.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00082.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00082.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00086.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00086.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00086.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00086.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00086.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00086.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00086.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00086.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00086.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00086.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00079.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00079.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00079.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00079.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00079.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00079.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00079.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00079.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00079.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00079.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00077.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00077.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00077.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00077.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00077.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00077.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00077.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00077.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00077.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00077.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00085.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00085.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00085.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00085.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00085.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00085.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00085.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00085.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00085.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00085.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00078.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00078.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00078.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00078.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00078.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00078.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00078.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00078.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00078.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00078.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00081.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00081.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00081.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00081.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00081.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00081.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00081.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00081.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00081.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00081.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00076.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00076.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00076.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00076.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00076.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00076.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00076.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00076.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00076.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00076.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00098.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00098.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00098.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00098.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00098.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00098.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00098.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00098.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00098.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00098.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00090.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00090.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00090.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00090.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00090.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00090.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00090.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00090.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00090.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00090.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00096.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00096.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00096.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00096.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00096.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00096.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00096.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00096.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00096.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00096.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00095.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00095.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00095.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00095.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00095.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00095.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00095.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00095.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00095.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00095.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00088.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00088.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00088.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00088.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00088.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00088.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00088.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00088.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00088.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00088.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00099.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00099.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00099.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00099.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00099.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00099.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00099.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00099.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00099.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00099.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00089.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00089.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00089.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00089.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00089.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00089.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00089.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00089.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00089.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00089.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00097.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00097.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00097.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00097.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00097.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00097.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00097.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00097.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00097.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00097.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00091.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00091.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00091.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00091.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00091.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00091.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00091.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00091.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00091.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00091.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00092.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00092.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00092.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00092.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00092.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00092.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00092.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00092.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00092.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00092.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00093.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00093.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00093.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00093.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00093.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00093.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00093.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00093.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00093.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00093.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00094.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00094.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00094.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00094.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00094.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00094.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00094.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00094.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00094.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00094.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00087.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00087.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00087.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00087.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00087.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00087.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00087.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00087.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00087.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00087.wav, segment:10
